# %% [markdown]
# #shift+enter --> new section

# %% [markdown]
# Kaggle Competition

# %%
import numpy as np
import pandas as pd

# %%
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv('test.csv')
gender_data = pd.read_csv('gender_submission.csv')
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
PassengerId_list = train_data['PassengerId'].tolist()
#print(PassengerId_list)

# %%
Survived_list = train_data['Survived'].tolist()
#val = train_data['Survived'].values[0]
#print(val)

cnt = 0
for i in range(len(Survived_list)):
    if train_data['Survived'].values[i] == 1:
        cnt+=1
        
print(cnt)
# Out:
# 342

# %%
#train_data.count()
#train_data.count(axis='columns')

# %%
train_data['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
copy = train_data

copy = copy.loc[copy["Survived"] != 0]

copy
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#loc = row select 기능

train_data.loc[2] #2번째 row
train_data.loc[2:4] #2~4번째 row
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#              Ticket    Fare Cabin Embarked
# 2  STON/O2. 3101282   7.925   NaN        S
# 3            113803  53.100  C123        S
# 4            373450   8.050   NaN        S

# %%
copy2 = train_data

copy2.loc[copy2['Pclass'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
copy3 = train_data

copy3 = copy3.loc[copy3['Survived'] == 1]
copy3['Pclass'].value_counts()
# Out:
# 1    136
# 3    119
# 2     87
# Name: Pclass, dtype: int64

# %%
#Total passenger # by gender

copy4 = train_data

copy4_m = copy4.loc[copy4['Sex'] == 'male']
copy4_f = copy4.loc[copy4['Sex'] == 'female']

cnt_m = copy4_m['Sex'].count()
cnt_f= copy4_f['Sex'].count()

DF = pd.DataFrame({'Total': [cnt_m,cnt_f]},
                  index=['Male', 'Female'])

plot = DF.plot.pie(y='Total', figsize=(5, 5))

# %%
#Gender to survived tolls

copy4_md = copy4_m.loc[copy4_m['Survived'] == 1]
copy4_fd = copy4_f.loc[copy4_f['Survived'] == 1]


cnt_m = copy4_md['Sex'].count()
cnt_f= copy4_fd['Sex'].count()

DF = pd.DataFrame({'Total Survived': [cnt_m,cnt_f]},
                  index=['Male', 'Female'])

plot = DF.plot.pie(y='Total Survived', figsize=(5, 5))

# %%
#Male death to survived

copy5_md = copy4_m.loc[copy4_m['Survived'] == 0]
copy5_ms = copy4_m.loc[copy4_m['Survived'] == 1]

cnt_md = copy5_md['Sex'].count()
cnt_ms= copy5_ms['Sex'].count()

DF = pd.DataFrame({'Male Death to Survived': [cnt_md,cnt_ms]},
                  index=['Male Death', 'Male Survived'])

plot = DF.plot.pie(y='Male Death to Survived', figsize=(5, 5))

# %%
#Female death to survived

copy5_fd = copy4_f.loc[copy4_f['Survived'] == 0]
copy5_fs = copy4_f.loc[copy4_f['Survived'] == 1]

cnt_fd = copy5_fd['Sex'].count()
cnt_fs= copy5_fs['Sex'].count()

DF = pd.DataFrame({'Female Death to Survived': [cnt_fd,cnt_fs]},
                  index=['Female Death', 'Female Survived'])

plot = DF.plot.pie(y='Female Death to Survived', figsize=(5, 5))

# %%
#숙제:
#Pclass, embarked로

# %%
#Pclass Total #

copy6 = train_data

copy6_1 = copy6.loc[copy6['Pclass'] == 1]
copy6_2 = copy6.loc[copy6['Pclass'] == 2]
copy6_3 = copy6.loc[copy6['Pclass'] == 3]

cnt_1 = copy6_1['Pclass'].count()
cnt_2= copy6_2['Pclass'].count()
cnt_3= copy6_3['Pclass'].count()

DF = pd.DataFrame({'Total': [cnt_1,cnt_2, cnt_3]},
                  index=['1', '2', '3'])

plot = DF.plot.pie(y='Total', figsize=(5, 5))


#Pclass Survival to Death of Pclass 1

copy6_1d = copy6_1.loc[copy6_1['Survived'] == 0]
copy6_1s = copy6_1.loc[copy6_1['Survived'] == 1]

cnt_1d = copy6_1d['Pclass'].count()
cnt_1s= copy6_1s['Pclass'].count()

DF = pd.DataFrame({'Pclass 1 Death to Survival': [cnt_1d,cnt_1s]},
                  index=['Pclass 1 Dead', 'Pclass 1 Survived'])

plot = DF.plot.pie(y='Pclass 1 Death to Survival', figsize=(5, 5), autopct='%1.1f%%')

# %%
#Embarked

copy7 = train_data

copy7_S = copy7.loc[copy7['Embarked'] == 'S']
copy7_C = copy7.loc[copy7['Embarked'] == 'C']
copy7_Q = copy7.loc[copy7['Embarked'] == 'Q']

cnt_S = copy7_S['Embarked'].count()
cnt_C = copy7_C['Embarked'].count()
cnt_Q = copy7_Q['Embarked'].count()

DF = pd.DataFrame({'Total': [cnt_S, cnt_C, cnt_C]},
                  index=['S', 'C', 'Q'])

plot = DF.plot.pie(y='Total', figsize=(5, 5))

# %%
#sns.countplot pandas

import seaborn as sns
import matplotlib.pyplot as plt

#df = sns.load_dataset('train_data')
copy8 = train_data
sns.countplot(x ='Embarked', data = copy8)
plt.show()

# %%
copy9 = train_data
copy9['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
copy10 = train_data.loc[train_data['Survived'] == 0]
copy10.head()
# Out:
#    PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0            1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4            5         0       3        Allen, Mr. William Henry  male  35.0
# 5            6         0       3                Moran, Mr. James  male   NaN
# 6            7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 7            8         0       3  Palsson, Master. Gosta Leonard  male   2.0
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500   NaN        S
# 4      0      0     373450   8.0500   NaN        S
# 5      0      0     330877   8.4583   NaN        Q
# 6      0      0      17463  51.8625   E46        S
# 7      3      1     349909  21.0750   NaN        S

# %%
#두가지 column 합치기
ax = sns.countplot(x="Embarked", hue="Survived", data=train_data)

# %%
train_data.groupby(['Pclass', 'Survived']).count()
# Out:
#                  PassengerId  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass Survived
# 1      0                  80    80   80   64     80     80      80    80
#        1                 136   136  136  122    136    136     136   136
# 2      0                  97    97   97   90     97     97      97    97
#        1                  87    87   87   83     87     87      87    87
# 3      0                 372   372  372  270    372    372     372   372
#        1                 119   119  119   85    119    119     119   119
#
#                  Cabin  Embarked
# Pclass Survived
# 1      0            59        80
#        1           117       134
# 2      0             3        97
#        1            13        87
# 3      0             6       372
#        1             6       119

# %%
copy11 = train_data[['SibSp','Survived']]
copy11
# Out:
#      SibSp  Survived
# 0        1         0
# 1        1         1
# 2        0         1
# 3        1         1
# 4        0         0
# ..     ...       ...
# 886      0         0
# 887      0         1
# 888      1         0
# 889      0         1
# 890      0         0
#
# [891 rows x 2 columns]

# %%
copy11.groupby(['SibSp']).mean()
# Out:
#        Survived
# SibSp
# 0      0.345395
# 1      0.535885
# 2      0.464286
# 3      0.250000
# 4      0.166667
# 5      0.000000
# 8      0.000000

# %%
df = train_data[['SibSp', 'Survived']].groupby(['SibSp']).mean()

df = df.sort_values(by='Survived' ,ascending=False) #False: greatest --> least
df
# Out:
#        Survived
# SibSp
# 1      0.535885
# 2      0.464286
# 0      0.345395
# 3      0.250000
# 4      0.166667
# 5      0.000000
# 8      0.000000

# %%
df = train_data[['Parch', 'Survived']].groupby(['Parch']).mean()


df = df.sort_values(by='Survived' ,ascending=False) #False: greatest --> least
df
# Out:
#        Survived
# Parch
# 3      0.600000
# 1      0.550847
# 2      0.500000
# 0      0.343658
# 5      0.200000
# 4      0.000000
# 6      0.000000

# %%
sns.factorplot(x ='SibSp', y ='Survived', data = train_data, aspect = 2.5)

plt.show()
# Out:
# /Users/macintosh/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x ='Parch', y ='Survived', data = train_data, aspect = 2.5)

plt.show()
# Out:
# /Users/macintosh/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
for dataset in train_and_test:
    dataset['Title'] = dataset.Name.str.extract('([A-Za-z]+)\.')
train_data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title
# 0      0         A/5 21171   7.2500   NaN        S    Mr
# 1      0          PC 17599  71.2833   C85        C   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss
# 3      0            113803  53.1000  C123        S   Mrs
# ...

# %%
#these are the used categorical features

cat = ['Sex', 'Pclass', 'Title']

#this dataframe contains the age and the categorical values 
df_age = train_data[cat + ['Age']].append(test_data[cat + ['Age']])
df_age
# Out:
#         Sex  Pclass   Title   Age
# 0      male       3      Mr  22.0
# 1    female       1     Mrs  38.0
# 2    female       3    Miss  26.0
# 3    female       1     Mrs  35.0
# 4      male       3      Mr  35.0
# ..      ...     ...     ...   ...
# 413    male       3      Mr   NaN
# 414  female       1    Dona  39.0
# 415    male       3      Mr  38.5
# 416    male       3      Mr   NaN
# 417    male       3  Master   NaN
#
# [1309 rows x 4 columns]

# %%
df_age_mean = round(df_age.dropna().groupby(cat, as_index=True).median(),1)
df_age_mean
# Out:
#                          Age
# Sex    Pclass Title
# female 1      Countess  33.0
#               Dona      39.0
#               Dr        49.0
#               Lady      48.0
#               Miss      30.0
#               Mlle      24.0
#               Mme       24.0
#               Mrs       45.0
#        2      Miss      20.0
#               Mrs       30.5
#               Ms        28.0
#        3      Miss      18.0
#               Mrs       31.0
# male   1      Capt      70.0
#               Col       54.5
#               Don       40.0
#               Dr        47.0
#               Jonkheer  38.0
#               Major     48.5
#               Master     6.0
#               Mr        41.5
#               Sir       49.0
#        2      Dr        38.5
#               Master     2.0
#               Mr        30.0
#               Rev       41.5
#        3      Master     6.0
#               Mr        26.0

# %%
def get_age(var, sex, pclass, title):
    """
    This function takes as input the categorical variables 
    and it returns the average age given the categorical variables 
    
    """
    if np.isnan(var):
        mean = df_age_mean['Age'][sex][pclass][title]
    else:
        mean = var
    return mean

# %%
df_age['Age2'] = df_age.apply(lambda x: get_age(x.Age, x.Sex, x.Pclass, x.Title), axis=1)
df_age[df_age['Age'].isna()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ms'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
for dataset in train_and_test:
    dataset['Age'] = train_data.apply(lambda x: get_age(x.Age, x.Sex, x.Pclass, x.Title), axis=1)

# %%
train_and_test = [train_data, test_data]
for dataset in train_and_test: # 각 data만큼 2번 실행
    dataset['Age'] = dataset['Age'].astype(int) 
    train_data['Age Range'] = pd.cut(train_data['Age'], bins = 5)
    dataset.loc[dataset['Age'] <= 16, 'Age'] = 0
    dataset.loc[dataset['Age'] > 16 & dataset['Age'] <= 32, 'Age'] = 1
    dataset.loc[dataset['Age'] > 32 & dataset['Age'] <= 48, 'Age'] = 2
    dataset.loc[dataset['Age'] > 48 & dataset['Age'] <= 64, 'Age'] = 3
    dataset.loc[dataset['Age'] > 64, 'Age'] = 4
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /var/folders/v5/r6n5tjq938dcct23z_shbd880000gn/T/ipykernel_7861/183355499.py in <module>
#       1 train_and_test = [train_data, test_data]
#       2 for dataset in train_and_test: # 각 data만큼 2번 실행
# ----> 3     dataset['Age'] = dataset['Age'].astype(int)
#       4     train_data['Age Range'] = pd.cut(train_data['Age'], bins = 5)
#       5     dataset.loc[dataset['Age'] <= 16, 'Age'] = 0
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ...
